# %%
import mysql.connector as sql
import pandas as pd
db = sql.connect(
    host="localhost",
    user="root",
    password="root14",
    database="ai"
)


query="SELECT * FROM salaries"

df=pd.read_sql(query,con=db)
df
# Out:
# C:\Users\vartika singh\AppData\Local\Temp\ipykernel_12636\4167209844.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,con=db)
#           Id       EmployeeName  \
# 0          1     NATHANIEL FORD
# 1          2       GARY JIMENEZ
# 2          3     ALBERT PARDINI
# 3          4  CHRISTOPHER CHONG
# 4          5    PATRICK GARDNER
# ...      ...                ...
# 3532    3533       GARY PEACHEY
# 3533    3534    SUSAN CLEVELAND
# 3534    3535   EVANGELINE REYES
# 3535    3536      SABINE BALDEN
# 3536  150000                  a
#
#                                             JobTitle    BasePay  OvertimePay  \
# 0     GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                    CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                    CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3               WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ...                                              ...        ...          ...
# 3532                              POLICE OFFICER III  112401.08     17455.97
# 3533                       ATTORNEY (CIVIL/CRIMINAL)  135481.62         0.00
# 3534                                REGISTERED NURSE  124007.20       122.10
# 3535                          FIRE FIGHTER PARAMEDIC  120837.78       962.13
# 3536                                               b      23.00        32.00
#
#        OtherPay Benefits   TotalPay  TotalPayBenefits  Year Notes  \
# 0     400184.25           567595.43         567595.43  2011
# 1     137811.38           538909.28         538909.28  2011
# 2      16452.60           335279.91         335279.91  2011
# 3     198306.90           332343.61         332343.61  2011
# 4     182234.59           326373.19         326373.19  2011
# ...         ...      ...        ...               ...   ...   ...
# 3532    5624.76           135481.81         135481.81  2011
# 3533       0.00           135481.62         135481.62  2011
# 3534   11346.42           135475.72         135475.72  2011
# 3535   13638.50           135438.41         135438.41  2011
# 3536      30.00       hi      21.00             20.00  2020    hi
#
#              Agency Status
# 0     San Francisco
# 1     San Francisco
# 2     San Francisco
# 3     San Francisco
# 4     San Francisco
# ...             ...    ...
# 3532  San Francisco
# 3533  San Francisco
# 3534  San Francisco
# 3535  San Francisco
# 3536             hi     hi
#
# [3537 rows x 13 columns]

# %% [markdown]
# # DISPLAY TOP 5 ROWS OF THE DATASET

# %%
df.head(5)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25           567595.43         567595.43
# 1  155966.02    245131.88  137811.38           538909.28         538909.28
# 2  212739.13    106088.18   16452.60           335279.91         335279.91
# 3   77916.00     56120.71  198306.90           332343.61         332343.61
# 4  134401.60      9737.00  182234.59           326373.19         326373.19
#
#    Year Notes         Agency Status
# 0  2011        San Francisco
# 1  2011        San Francisco
# 2  2011        San Francisco
# 3  2011        San Francisco
# 4  2011        San Francisco

# %% [markdown]
# # CHECK LAST 3 ROWS OF THE DATASET

# %%
df.tail(3)
# Out:
#           Id      EmployeeName                JobTitle    BasePay  \
# 3534    3535  EVANGELINE REYES        REGISTERED NURSE  124007.20
# 3535    3536     SABINE BALDEN  FIRE FIGHTER PARAMEDIC  120837.78
# 3536  150000                 a                       b      23.00
#
#       OvertimePay  OtherPay Benefits   TotalPay  TotalPayBenefits  Year Notes  \
# 3534       122.10  11346.42           135475.72         135475.72  2011
# 3535       962.13  13638.50           135438.41         135438.41  2011
# 3536        32.00     30.00       hi      21.00             20.00  2020    hi
#
#              Agency Status
# 3534  San Francisco
# 3535  San Francisco
# 3536             hi     hi

# %% [markdown]
# # FIND SHAPE OF OUR DATASET(NUMBER OF ROWS & NUMBER OF COLUMNS)

# %%
print(df.shape[0])
print(df.shape[1])
# Out:
# 3537
# 13

# %% [markdown]
# # GET INFORMATION ABOUT OUR DATASET LIKE TOTAL NUMBER ROWS,TOTAL NUMBER OF COLUMNS,DATATYPE OF EACH COLUMN AND MEMORY REQUIREDMENT

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3537 entries, 0 to 3536
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                3537 non-null   int64
#  1   EmployeeName      3537 non-null   object
#  2   JobTitle          3537 non-null   object
#  3   BasePay           3537 non-null   float64
#  4   OvertimePay       3537 non-null   float64
#  5   OtherPay          3537 non-null   float64
#  6   Benefits          3537 non-null   object
#  7   TotalPay          3537 non-null   float64
#  8   TotalPayBenefits  3537 non-null   float64
#  9   Year              3537 non-null   int64
#  10  Notes             3537 non-null   object
#  11  Agency            3537 non-null   object
#  12  Status            3537 non-null   object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 359.4+ KB

# %% [markdown]
# # GET OVERALL STATISTICS ABOUT THE DATAFRAME

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count    3537.000000    3537.000000    3537.000000    3537.000000
# mean     1810.408821  131342.196342   17305.918470   14285.811702
# std      2693.352679   29945.173448   23092.119672   18085.121600
# min         1.000000       0.000000       0.000000       0.000000
# 25%       885.000000  110328.940000       0.000000    3287.950000
# 50%      1769.000000  130343.720000    7816.300000   11377.280000
# 75%      2653.000000  149044.930000   26074.890000   17998.040000
# max    150000.000000  294580.020000  245131.880000  400184.250000
#
#             TotalPay  TotalPayBenefits         Year
# count    3537.000000       3537.000000  3537.000000
# mean   162933.908420     162933.908137  2011.002545
# std     26717.511535      26717.513259     0.151330
# min        21.000000         20.000000  2011.000000
# 25%    144642.390000     144642.390000  2011.000000
# 50%    156693.690000     156693.690000  2011.000000
# 75%    173757.660000     173757.660000  2011.000000
# max    567595.430000     567595.430000  2020.000000

# %% [markdown]
# # DATA FILTERING

# %%
df.columns
df['Year'].tail(29)
# Out:
# 3508    2011
# 3509    2011
# 3510    2011
# 3511    2011
# 3512    2011
# 3513    2011
# 3514    2011
# 3515    2011
# 3516    2011
# 3517    2011
# 3518    2011
# 3519    2011
# 3520    2011
# 3521    2011
# 3522    2011
# 3523    2011
# 3524    2011
# 3525    2011
# 3526    2011
# 3527    2011
# 3528    2011
# 3529    2011
# 3530    2011
# 3531    2011
# 3532    2011
# 3533    2011
# 3534    2011
# 3535    2011
# 3536    2020
# Name: Year, dtype: int64

# %% [markdown]
# # CHECK NULL VALUES IN THE DATASET

# %%
df.isnull()
# Out:
#          Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  Benefits  \
# 0     False         False     False    False        False     False     False
# 1     False         False     False    False        False     False     False
# 2     False         False     False    False        False     False     False
# 3     False         False     False    False        False     False     False
# 4     False         False     False    False        False     False     False
# ...     ...           ...       ...      ...          ...       ...       ...
# 3532  False         False     False    False        False     False     False
# 3533  False         False     False    False        False     False     False
# 3534  False         False     False    False        False     False     False
# 3535  False         False     False    False        False     False     False
# 3536  False         False     False    False        False     False     False
#
#       TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# 0        False             False  False  False   False   False
# 1        False             False  False  False   False   False
# 2        False             False  False  False   False   False
# 3        False             False  False  False   False   False
# 4        False             False  False  False   False   False
# ...        ...               ...    ...    ...     ...     ...
# 3532     False             False  False  False   False   False
# 3533     False             False  False  False   False   False
# 3534     False             False  False  False   False   False
# 3535     False             False  False  False   False   False
# 3536     False             False  False  False   False   False
#
# [3537 rows x 13 columns]

# %% [markdown]
# # DROP THE COLUMN

# %%
df.columns
df.drop('Status',axis=1)
# Out:
#           Id       EmployeeName  \
# 0          1     NATHANIEL FORD
# 1          2       GARY JIMENEZ
# 2          3     ALBERT PARDINI
# 3          4  CHRISTOPHER CHONG
# 4          5    PATRICK GARDNER
# ...      ...                ...
# 3532    3533       GARY PEACHEY
# 3533    3534    SUSAN CLEVELAND
# 3534    3535   EVANGELINE REYES
# 3535    3536      SABINE BALDEN
# 3536  150000                  a
#
#                                             JobTitle    BasePay  OvertimePay  \
# 0     GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                    CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                    CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3               WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ...                                              ...        ...          ...
# 3532                              POLICE OFFICER III  112401.08     17455.97
# 3533                       ATTORNEY (CIVIL/CRIMINAL)  135481.62         0.00
# 3534                                REGISTERED NURSE  124007.20       122.10
# 3535                          FIRE FIGHTER PARAMEDIC  120837.78       962.13
# 3536                                               b      23.00        32.00
#
#        OtherPay Benefits   TotalPay  TotalPayBenefits  Year Notes  \
# 0     400184.25           567595.43         567595.43  2011
# 1     137811.38           538909.28         538909.28  2011
# 2      16452.60           335279.91         335279.91  2011
# 3     198306.90           332343.61         332343.61  2011
# 4     182234.59           326373.19         326373.19  2011
# ...         ...      ...        ...               ...   ...   ...
# 3532    5624.76           135481.81         135481.81  2011
# 3533       0.00           135481.62         135481.62  2011
# 3534   11346.42           135475.72         135475.72  2011
# 3535   13638.50           135438.41         135438.41  2011
# 3536      30.00       hi      21.00             20.00  2020    hi
#
#              Agency
# 0     San Francisco
# 1     San Francisco
# 2     San Francisco
# 3     San Francisco
# 4     San Francisco
# ...             ...
# 3532  San Francisco
# 3533  San Francisco
# 3534  San Francisco
# 3535  San Francisco
# 3536             hi
#
# [3537 rows x 12 columns]

# %%
import mysql.connector as sql
import pandas as pd
db = sql.connect(
    host="localhost",
    user="root",
    password="root14",
    database="ai"
)


query="SELECT * FROM train"

df=pd.read_sql(query,con=db)
df
# Out:
# C:\Users\vartika singh\AppData\Local\Temp\ipykernel_12636\4095984702.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,con=db)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# 709               Rice, Mrs. William (Margaret Norton)  female   39      0
# 710                              Montvila, Rev. Juozas    male   27      0
# 711                       Graham, Miss. Margaret Edith  female   19      0
# 712                              Behr, Mr. Karl Howell    male   26      0
# 713                                Dooley, Mr. Patrick    male   32      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500              S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250              S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500              S
# ..     ...               ...      ...   ...      ...
# 709      5            382652  29.1250              Q
# 710      0            211536  13.0000              S
# 711      0            112053  30.0000   B42        S
# 712      0            111369  30.0000  C148        C
# 713      0            370376   7.7500              Q
#
# [714 rows x 12 columns]

# %% [markdown]
# # HANDLE MISSING VALUES

# %%
missing_values = df.isnull().sum()
print("Missing values:\n", missing_values)
# Out:
# Missing values:
#  PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # CATEGORICAL DATA ENCODING

# %% [markdown]
# # WHAT IS UNIVARIATE ANALYSIS

# %%
df.columns
df['PassengerId'].describe()
# Out:
# count    714.000000
# mean     448.582633
# std      259.119524
# min        1.000000
# 25%      222.250000
# 50%      445.000000
# 75%      677.750000
# max      891.000000
# Name: PassengerId, dtype: float64

# %% [markdown]
# # HOW MANY PEOPLE SURVIVED AND HOW MANY DIED PLOT ON GRAPH

# %%
import matplotlib.pyplot as plt

# Group the data by the 'Survived' column and count the occurrences of each category
survived_count = df['Survived'].value_counts()

# Plot the counts
plt.figure(figsize=(8, 6))
plt.bar(survived_count.index, survived_count.values, color=['red', 'green'])
plt.xticks(survived_count.index, ['Died', 'Survived'])
plt.xlabel('Outcome')
plt.ylabel('Number of People')
plt.title('Number of People Survived and Died')
plt.show()

# %% [markdown]
# # HOW MANY PASSENGERS WERE IN FIRST CLASS,SECOND CLASS AND THIRD CLASS PLOT THOSE FIGURES ON GRAPH

# %%
class_count = df['Pclass'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 6))
plt.pie(class_count, labels=class_count.index, autopct='%1.1f%%', colors=['blue', 'green', 'red'])
plt.title('Distribution of Passengers by Class')
plt.legend(labels=['1st Class', '2nd Class', '3rd Class'], loc='upper right')

plt.show()

# %% [markdown]
# # NUMBER  OF MALE AND FEMALE PASSANGERS

# %%
df.columns
class_cot = df['Sex'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(class_cot.index, class_cot.values, color=['red', 'green'])
plt.xticks(class_cot.index, ['male', 'female'])
plt.xlabel('Outcome')
plt.ylabel('Number of People')
plt.title('Number of People female and male')
plt.show()

# %% [markdown]
# # BIVARIANT ANALSIS

# %%
data.columns
plt.figure(figsize=(8, 6))
plt.scatter(data['PassengerId'], data['Fare'], color='blue', alpha=0.7)
plt.xlabel('Variable 1')
plt.ylabel('Variable 2')
plt.title('Scatter Plot of Variable 1 vs Variable 2')
plt.show()

# %% [markdown]
# # HOW HAS BETTER CANCE OF SURVIVAL MALE OR FEMALE

# %%
survival_pivot = data.pivot_table(index='Sex', columns='Survived', aggfunc='size', fill_value=0)

# Plot the survival rates
survival_pivot.plot(kind='bar', stacked=True, figsize=(8, 6), color=['red', 'green'])
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Survival Count by Sex')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # WHICH PASSENGER CLASS HAS BETTER CHANCE OF SURVIVAL(FIRST,SECOND,OR THIRD CLASS)?

# %%
survival_pivot = data.pivot_table(index='Pclass', columns='Survived', aggfunc='size', fill_value=0)

# Plot the survival rates
survival_pivot.plot(kind='bar', stacked=True, figsize=(8, 6), color=['red', 'green'])
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.title('Survival Count by Passenger Class')
plt.legend(title='Survived', labels=['No', 'Yes'])

plt.show()

# %% [markdown]
# # FEATURE ENGINEERING
